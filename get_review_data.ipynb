# %% [markdown]
# <a href="https://colab.research.google.com/github/muhajirakbarhsb/NLP_class_2023/blob/main/get_review_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google_play_scraper
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.4

# %%
from google_play_scraper import Sort, reviews_all
import pandas as pd

# %%
result = reviews_all(
        'com.myorbit',
        sleep_milliseconds=0, # defaults to 0
        lang='id', # defaults to 'en'
        country='id', # defaults to 'us'
        sort=Sort.NEWEST
    )

# %%
dfItem = pd.DataFrame.from_records(result)

# %%
dfItem
# Out:
#                                    reviewId          userName  \
# 0      385f80f3-d5a9-430c-b50f-cf6e821cf874    Jukarnain Juka
# 1      43e1d5fd-5ac5-45ab-8f1d-b516725c7030   ebzan laniengka
# 2      14239cb9-f837-44dd-a0ab-d5ea596d9465     Agus Sugiarto
# 3      61f4853a-209e-4a0c-ac4d-382fcfcf99b1     AHADIN SUBIHI
# 4      b7fb5eb3-5391-496e-8d6f-8ed54d134c34      Agus Sutisna
# ...                                     ...               ...
# 21575  2a07a879-5d3a-4c55-9686-d2f1d629be6a  ALFAIZNA Channel
# 21576  d7d1ceda-44b5-4ccf-95ab-604b922ccb4d     tubagus fandi
# 21577  94d6eefd-b333-44f1-803d-3ea31193795e        agus habib
# 21578  cd6d79a9-bdf4-4a74-a0e2-584bee46eb58    Dwi Aji Kusuma
# 21579  22594202-4401-4119-8845-74aecaec85aa       Adi Pratomo
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/AD_cM...
# 1      https://play-lh.googleusercontent.com/a-/AD_cM...
# 2      https://play-lh.googleusercontent.com/a-/AD_cM...
# 3      https://play-lh.googleusercontent.com/a-/AD_cM...
# 4      https://play-lh.googleusercontent.com/a-/AD_cM...
# ...                                                  ...
# 21575  https://play-lh.googleusercontent.com/a-/AD_cM...
# 21576  https://play-lh.googleusercontent.com/a/AAcHTt...
# 21577  https://play-lh.googleusercontent.com/a-/AD_cM...
# 21578  https://play-lh.googleusercontent.com/a-/AD_cM...
# 21579  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                                  content  score  \
# 0                                                   Good      5
# 1      Kalau mau lihat perangkat yang terhubung gak b...      1
# 2      Mohon di perbaiki bug aplikasi ini, banyak sek...      1
# 3      TOLONG DI PERBAIKI YA KA APPLIKASI NYA SAAT SA...      3
# 4      TIDAK DIREKOMENDASIKAN SAMA SEKALI.. SUDAH BAN...      1
# ...                                                  ...    ...
# 21575  Bagus, tapi masih harus dilengkapi fitur yg bl...      5
# 21576                      Mantaaap.... gak pke ribet...      5
# 21577                            Kasih 4 bintang dulu ya      4
# 21578  Woi, gw mau register orbit krn tertarik sama p...      3
# 21579  Mantap ! Setelah download aplikasi gak terjadi...      5
#
#        thumbsUpCount reviewCreatedVersion                  at  \
# 0                  0               0.69.2 2023-09-04 01:34:10
# 1                  0               0.69.2 2023-09-03 23:54:14
# 2                  4              0.67.16 2023-09-03 20:19:18
# 3                  0               0.69.2 2023-09-03 13:35:54
# 4                  0               0.69.2 2023-09-03 12:52:15
# ...              ...                  ...                 ...
# 21575              1               0.8.23 2020-05-25 18:34:40
# 21576              2               0.8.20 2020-05-22 05:17:46
# 21577              0                 None 2020-05-19 21:47:11
# 21578              3               0.8.20 2020-05-19 17:17:52
# 21579              1               0.8.20 2020-05-18 22:18:02
#
#                                             replyContent           repliedAt  \
# 0                                                   None                 NaT
# 1                                                   None                 NaT
# 2      Dear, Agus Sugiarto. Mohon maaf atas ketidakny... 2023-02-15 05:29:31
# 3                                                   None                 NaT
# 4                                                   None                 NaT
# ...                                                  ...                 ...
# 21575                                               None                 NaT
# 21576                                               None                 NaT
# 21577                                               None                 NaT
# 21578                                               None                 NaT
# 21579                                               None                 NaT
#
#       appVersion
# 0         0.69.2
# 1         0.69.2
# 2        0.67.16
# 3         0.69.2
# 4         0.69.2
# ...          ...
# 21575     0.8.23
# 21576     0.8.20
# 21577       None
# 21578     0.8.20
# 21579     0.8.20
#
# [21580 rows x 11 columns]

# %%
dfItem = dfItem[['at', 'content', 'score', 'userName','replyContent']]

# %%
min_tanggal = dfItem['at'].min()
max_tanggal = dfItem['at'].max()

print(f"data dimulai dari {min_tanggal} sampai {max_tanggal}")
# Out:
# data dimulai dari 2020-05-18 22:18:02 sampai 2023-09-04 01:34:10

# %%
dfItem.head(30)['content'].values
# Out:
# array(['Good',
#        'Kalau mau lihat perangkat yang terhubung gak bisa, langsung auto keluar dari aplikasinya, tolong perbaiki lagi. 🙏',
#        'Mohon di perbaiki bug aplikasi ini, banyak sekali bug, apalagi pada saat isi paket untuk bulan selanjutnya sering gagal padahal pulsa terisi dan mohon di tambah fitur auto perpanjang pada tgl yg sudah di tentukan masa tenggang paket habis dan bila ada pulsa yg ada di aplikasi.',
#        'TOLONG DI PERBAIKI YA KA APPLIKASI NYA SAAT SAYA PENCET PERANGKAT TERHUBUNG KELUAR SENDIRI MULU DARI APPLIKASI NYA 😭😭😭DAN AKUN YANG SUDAH ADA ENGGAK BISA KELUAR LAGI DARI APPLIKASI NYA KA DAN AKUN SAYA SUDAH KE 7 KALI LOGIN SUDAH KA KARNA AKUN NYA SERING KELUAR DARI APPLIKASI NYA DAN SEKARANG DI SURUH LOGIN LAGI AKUNNYA 🙏😭',
#        'TIDAK DIREKOMENDASIKAN SAMA SEKALI.. SUDAH BANYAK GANGGUANNYA, LAMPU INDIKATOR SINYAL MERAH TERUS.. HARGA MAHAL, PELAYANAN CUEK.. DISURUH MENUNGGU TERUS.. KAPOK BELI INI..',
#        'Beli paket pembayaran VA dah 2 hari ga masuk2 dah komplain tapi belum ada kejelasan haduuh no recommend dah servicenya',
#        'Ribet amat skrg harus login trus',
#        'Isi kuotanya pakai bca virtual account,ngga masuk2 kuotanya,di mohon nunggu ntah sampai kapan!orang perlu kuotanya skrg,ngga profesional bgt',
#        'Ini apasih wifi sering tidak bisa terhubung, sering logout, mau login lagi susah, anehh',
#        'susah daftatnya, sudah beli modem pas daftar disurubeli modem lagi. lebih baik daftar manual. harga juga tidak sesuai di promo. mahalllll promonya saja yg murah pembelian paket tetap MAHAL',
#        'JANGAN JUAL PRODUK SAMPAH BOSS..!! ORBIT MAHAL, JARINGAN CUMA BAGUS DI BULAN PERTAMA, APLIKASI EROR, SERING FORCE CLOSE, GANTI NAMA PERANGKAT YANG TERHUBUNG BISA TAPI SETELAH KELUAR APLIKASI (LOGIN ULANG) SAAT CEK PERANGKAT TERHUBUNG LANGSUNG EROR APLIKASI, PULSA TERPOTONG KUOTA BELUM MASUK, AKUN TIDAK TERDAFTAR SAAT LOGIN (PADAHAL NOMER ITU SUDAH BENAR), PROTES DI PLAYSTORE CUMA NGOMONG SILAHKAN HUBUNGI INSTAGRAM (TIDAK DIRESPON) EMAIL (TIDAK DIRESPON) NOMER WHATSAAP (TIDAK TERDAFTAR) 💩💩',
#        'iklan tidak bisa d close parah',
#        'Selalu gagal login. Password masuk ke aplikasi my orbit selalu salah padahal sudah beberapa kali ganti. 🤦\u200d♂️',
#        'Sering logout, dan jika login harus masukan kartu SIM di hp untuk mendapatkan kode otp. Sangat ribet. Apalagi ketika saya berada jauh dari modem orbitnya.',
#        'Anying benar pihak telkomsel ini,,paket makin lama makin mahal,,sinyal orbit makin sulit,,anji*9',
#        'Bigung mau beli paket data di aplikasi slalu muat ulang muat ulang gimana mau isi payah',
#        'Gak jelas!',
#        'Orbit oh orbit aplikasimu ga sesuai janjimu, alat sering error jaringan juga ahhhhh Mending pake my Republik atau sejenis daripada orbit',
#        'Kenapa saya tidak bisa login ke aplikasi my orbit ?? Disitu di bilang terjadi kesalahan sistem .. mohon di balas',
#        'Pada saat akan membuka perangkat yang terhubung aplikasi tiba2 keluar sendiri kecewa,harga paket naik asuu',
#        'orbit makin mahal sekerang',
#        'Tolong deh di perbaiki lagi untuk costumer servicenya. Saya terkendala beli paket orbit sudah melakukan pembayaran tapi paket data belum bertambah. Sudah chat lewat si veronika gak ada respon. Uang 100ribu mungkin bukan uang banyak tapi seberapa banyak kalian ambil itu uang haram. Gak ikhlas saya seumur hidup',
#        'Sering long off dari hp yg terdaftar harus login ulang mengunakan kartu yg tertanam di orbit.',
#        'Mau isi ulang kuota tapi error tolong diperbaiki di aplikasinya 🙏',
#        'Semakin kesini semakun mahal dan lelet',
#        'Ya bener mi orbit pertama di pakai lancar lama2 paket nya mahal di tambah lagi jarang bisa di pakai sinyalny tmbh susah ngk bisa setabil nyesel q beli .',
#        'Sangat tidak di sarankan untuk beli soalny cuma bylan pertama yg lancar akses internetnya dan setelah itu parah lemot masih lebih cepat kalau kaki seribu pakai sepatu',
#        'Gak tau kenapa ya gak bisa login, padahal udah daftar nomornya. Aplikasi aneh',
#        'Mau ganti imail nunggu satu abat link endak di kirim lamaaaaa banget respont nya',
#        'Keluar sendiri dari aplikasi selalu dan berulang kali, paketannya makin mahal ga kayak pas pertama skrng 200rb cuman dapat 130gb aja ga kayak dulu 150gb ga nyampe 200rb. Sinyal bagus pas pertama makin hari makin parah.'],
#       dtype=object)

# %%
dfItem['content'].head(30)
# Out:
# 0                                                  Good
# 1     Kalau mau lihat perangkat yang terhubung gak b...
# 2     Mohon di perbaiki bug aplikasi ini, banyak sek...
# 3     TOLONG DI PERBAIKI YA KA APPLIKASI NYA SAAT SA...
# 4     TIDAK DIREKOMENDASIKAN SAMA SEKALI.. SUDAH BAN...
# 5     Beli paket pembayaran VA dah 2 hari ga masuk2 ...
# 6                      Ribet amat skrg harus login trus
# 7     Isi kuotanya pakai bca virtual account,ngga ma...
# 8     Ini apasih wifi sering tidak bisa terhubung, s...
# 9     susah daftatnya, sudah beli modem pas daftar d...
# 10    JANGAN JUAL PRODUK SAMPAH BOSS..!! ORBIT MAHAL...
# 11                       iklan tidak bisa d close parah
# 12    Selalu gagal login. Password masuk ke aplikasi...
# 13    Sering logout, dan jika login harus masukan ka...
# 14    Anying benar pihak telkomsel ini,,paket makin ...
# 15    Bigung mau beli paket data di aplikasi slalu m...
# 16                                           Gak jelas!
# 17    Orbit oh orbit aplikasimu ga sesuai janjimu, a...
# 18    Kenapa saya tidak bisa login ke aplikasi my or...
# 19    Pada saat akan membuka perangkat yang terhubun...
# 20                           orbit makin mahal sekerang
# 21    Tolong deh di perbaiki lagi untuk costumer ser...
# 22    Sering long off dari hp yg terdaftar harus log...
# 23    Mau isi ulang kuota tapi error tolong diperbai...
# 24               Semakin kesini semakun mahal dan lelet
# 25    Ya bener mi orbit pertama di pakai lancar lama...
# 26    Sangat tidak di sarankan untuk beli soalny cum...
# 27    Gak tau kenapa ya gak bisa login, padahal udah...
# 28    Mau ganti imail nunggu satu abat link endak di...
# 29    Keluar sendiri dari aplikasi selalu dan berula...
# Name: content, dtype: object
